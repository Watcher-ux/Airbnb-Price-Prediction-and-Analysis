# %% [markdown]
# # Preprocessing data before Applied Machine Learning operations and Training.

# %%
import pandas as pd
import numpy as np
import re
from collections import Counter
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Load data

# %%
path='C:/Zcommon/trainee/project_1/albany_nyc_cleansed_part_2.csv'
df=pd.read_csv(path)
df.head()
# Out:
#   host_response_time  host_response_rate  host_acceptance_rate  \
# 0            unknown               100.0                  50.0
# 1     within an hour               100.0                 100.0
# 2     within an hour               100.0                  99.0
# 3     within an hour               100.0                 100.0
# 4            unknown               100.0                 100.0
#
#    host_is_superhost  host_listings_count  host_total_listings_count  \
# 0                  0                    1                          5
# 1                  1                    5                          5
# 2                  0                    2                          2
# 3                  1                    5                          5
# 4                  1                    1                          1
#
#    host_has_profile_pic  host_identity_verified neighbourhood_cleansed  \
# 0                     1                       1             THIRD WARD
# 1                     1                       1             SIXTH WARD
# 2                     1                       1            SECOND WARD
# 3                     1                       1             SIXTH WARD
# 4                     1                       1             SIXTH WARD
#
#    latitude  ...  reviews_per_month has_reviews first_review_missing  \
# 0  42.65789  ...               0.07           1                    0
# 1  42.65222  ...               2.29           1                    0
# 2  42.64615  ...               2.94           1                    0
# 3  42.65222  ...               2.64           1                    0
# 4  42.65559  ...               5.58           1                    0
#
#    last_review_missing  days_since_first_review days_since_last_review  \
# 0                    0                     4164                   1195
# 1                    0                     4119                    112
# 2                    0                     3853                     70
# 3                    0                     3823                    147
# 4                    0                     3396                    113
#
#    has_availability_miss  superhost_missing host_tenure_days  \
# 0                      0                  0             4704
# 1                      0                  0             4127
# 2                      0                  0             3909
# 3                      0                  0             4127
# 4                      0                  0             4158
#
#    last_scraped_collected_days
# 0                           50
# 1                           49
# 2                           49
# 3                           50
# 4                           50
#
# [5 rows x 59 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 425 entries, 0 to 424
# Data columns (total 59 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   host_response_time              425 non-null    object
#  1   host_response_rate              425 non-null    float64
#  2   host_acceptance_rate            425 non-null    float64
#  3   host_is_superhost               425 non-null    int64
#  4   host_listings_count             425 non-null    int64
#  5   host_total_listings_count       425 non-null    int64
#  6   host_has_profile_pic            425 non-null    int64
#  7   host_identity_verified          425 non-null    int64
#  8   neighbourhood_cleansed          425 non-null    object
#  9   latitude                        425 non-null    float64
#  10  longitude                       425 non-null    float64
#  11  property_type                   425 non-null    object
#  12  room_type                       425 non-null    object
#  13  accommodates                    425 non-null    int64
#  14  bathrooms                       425 non-null    float64
#  15  bathrooms_text                  425 non-null    object
#  16  bedrooms                        425 non-null    float64
#  17  beds                            425 non-null    float64
#  18  amenities                       425 non-null    object
#  19  price                           425 non-null    float64
#  20  minimum_nights                  425 non-null    int64
#  21  maximum_nights                  425 non-null    int64
#  22  minimum_minimum_nights          425 non-null    int64
#  23  maximum_minimum_nights          425 non-null    int64
#  24  minimum_maximum_nights          425 non-null    int64
#  25  maximum_maximum_nights          425 non-null    int64
#  26  minimum_nights_avg_ntm          425 non-null    float64
#  27  maximum_nights_avg_ntm          425 non-null    float64
#  28  has_availability                425 non-null    int64
#  29  availability_30                 425 non-null    int64
#  30  availability_60                 425 non-null    int64
#  31  availability_90                 425 non-null    int64
#  32  availability_365                425 non-null    int64
#  33  number_of_reviews               425 non-null    int64
#  34  number_of_reviews_ltm           425 non-null    int64
#  35  number_of_reviews_l30d          425 non-null    int64
#  36  availability_eoy                425 non-null    int64
#  37  number_of_reviews_ly            425 non-null    int64
#  38  estimated_occupancy_l365d       425 non-null    int64
#  39  estimated_revenue_l365d         425 non-null    float64
#  40  review_scores_rating            425 non-null    float64
#  41  review_scores_accuracy          425 non-null    float64
#  42  review_scores_cleanliness       425 non-null    float64
#  43  review_scores_checkin           425 non-null    float64
#  44  review_scores_communication     425 non-null    float64
#  45  review_scores_location          425 non-null    float64
#  46  review_scores_value             425 non-null    float64
#  47  instant_bookable                425 non-null    int64
#  48  calculated_host_listings_count  425 non-null    int64
#  49  reviews_per_month               425 non-null    float64
#  50  has_reviews                     425 non-null    int64
#  51  first_review_missing            425 non-null    int64
#  52  last_review_missing             425 non-null    int64
#  53  days_since_first_review         425 non-null    int64
#  54  days_since_last_review          425 non-null    int64
#  55  has_availability_miss           425 non-null    int64
#  56  superhost_missing               425 non-null    int64
#  57  host_tenure_days                425 non-null    int64
#  58  last_scraped_collected_days     425 non-null    int64
# dtypes: float64(19), int64(34), object(6)
# memory usage: 196.0+ KB

# %% [markdown]
# ## One hot encoding 'room_type' and 'property_type' as it has limited categorical values.

# %%
df=pd.get_dummies(df,columns=['room_type','property_type','neighbourhood_cleansed'])

# %% [markdown]
# ### Deal with 'amenities' : This is very complex to deal with as there are many amenities associated with some airbnb's, so lets gather the top 40 amenities and create a feature for each.

# %% [markdown]
# #### Helping function

# %%
def parse_amenities(s):##Ai
    if pd.isna(s): return []
    s = str(s).strip()
    if s.startswith("{") and s.endswith("}"):
        s = s[1:-1]
    parts = [p.strip().strip('"').strip("'") for p in s.split(",") if p.strip()!='']
    return [p for p in parts if p]

# parse
amen_lists = df['amenities'].apply(parse_amenities)

# top-K
K = 40
counter = Counter()
for lst in amen_lists:
    counter.update(lst)
top_k = [a for a,c in counter.most_common(K)]

# create binary columns for top-K
for amen in top_k:
    col = "amenity__" + amen.replace(" ", "_").replace(":", "").replace("/", "_")
    df[col] = amen_lists.apply(lambda lst: 1 if amen in lst else 0)

# amenities count
df['amenities_count'] = amen_lists.apply(len)

# %%
# Now drop 'amenities' containing raw data as its useless at this point.
df=df.drop(columns=['amenities'])

# %% [markdown]
# ## Now for bathroom_text from this we just need to extract the type(shared or private) and create a new feature bathroom_private having binary answers.

# %%
def extract_bathroom_type(text):
    if pd.isna(text):
        return 1  # assume private unless "shared"
    t = text.lower()
    if "shared" in t:
        return 0
    return 1

df['bathroom_private'] = df['bathrooms_text'].apply(extract_bathroom_type)

# drop the original messy column
df = df.drop(columns=['bathrooms_text'])

# %% [markdown]
# ## Lastly host_response_time, we use ordinal encoding to encode this feature.

# %%
mappings={
    'within an hour':4,'within a few hours':3,'within a day':2,'a few days or more':1,'unknown':0
}
df['encoded_host_response_time']=df['host_response_time'].map(mappings)
#dropping the original feature as its useless now.
df=df.drop(columns=['host_response_time'])

# %%
df.head()
# Out:
#    host_response_rate  host_acceptance_rate  host_is_superhost  \
# 0               100.0                  50.0                  0
# 1               100.0                 100.0                  1
# 2               100.0                  99.0                  0
# 3               100.0                 100.0                  1
# 4               100.0                 100.0                  1
#
#    host_listings_count  host_total_listings_count  host_has_profile_pic  \
# 0                    1                          5                     1
# 1                    5                          5                     1
# 2                    2                          2                     1
# 3                    5                          5                     1
# 4                    1                          1                     1
#
#    host_identity_verified  latitude  longitude  accommodates  ...  \
# 0                       1  42.65789  -73.75370             4  ...
# 1                       1  42.65222  -73.76724             3  ...
# 2                       1  42.64615  -73.75966             2  ...
# 3                       1  42.65222  -73.76724             2  ...
# 4                       1  42.65559  -73.76506             4  ...
#
#    amenity__Toaster  amenity__Dishwasher  amenity__Hot_water_kettle  \
# 0                 0                    0                          0
# 1                 1                    1                          0
# 2                 1                    0                          1
# 3                 0                    1                          0
# 4                 0                    1                          0
#
#    amenity__Bathtub  amenity__Shower_gel  amenity__Air_conditioning  \
# 0                 0                    0                          1
# 1                 0                    1                          0
# 2                 0                    1                          1
# 3                 0                    1                          0
# 4                 0                    1                          0
#
#    amenity__Stove  amenities_count  bathroom_private  \
# 0               0                8                 1
# 1               1               39                 1
# 2               1               40                 1
# 3               1               37                 1
# 4               1               33                 1
#
#    encoded_host_response_time
# 0                           0
# 1                           4
# 2                           4
# 3                           4
# 4                           0
#
# [5 rows x 131 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 425 entries, 0 to 424
# Columns: 131 entries, host_response_rate to encoded_host_response_time
# dtypes: bool(35), float64(19), int64(77)
# memory usage: 333.4 KB

# %%
df.to_csv('model_training_data.csv',index=False)

# %% [markdown]
# ## Now we move to Model Training processes in the predictions notebook.

# %% [markdown]
# # End
