# %% [markdown]
# # ML-preprocessig steps to encode and feature engineer

# %%
import pandas as pd
import numpy as np
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Load data

# %%
path='C:/Zcommon/trainee/project_1/dataset_part2_amster.csv'
df=pd.read_csv(path)
df.head()
# Out:
#       id last_scraped                                               name  \
# 0  27886   2025-09-11  Romantic, stylish B&B houseboat in canal district
# 1  28871   2025-09-11                            Comfortable double room
# 2  29051   2025-09-11                   Comfortable single / double room
# 3  49552   2025-09-11       Multatuli Luxury Guest Suite in top location
# 4  50263   2025-09-11         Central de Lux 2 bedrooms (4p) apt 125 sqm
#
#    host_since  host_response_time  host_response_rate  host_acceptance_rate  \
# 0  2010-03-23      within an hour               100.0                  97.0
# 1  2010-05-13      within an hour               100.0                  99.0
# 2  2010-05-13      within an hour               100.0                  99.0
# 3  2010-09-06  within a few hours               100.0                  93.0
# 4  2010-09-10      within an hour               100.0                 100.0
#
#    host_is_superhost  host_listings_count  host_total_listings_count  ...  \
# 0                  1                  1.0                        1.0  ...
# 1                  1                  2.0                        2.0  ...
# 2                  1                  2.0                        2.0  ...
# 3                  1                  1.0                        2.0  ...
# 4                  0                  1.0                        1.0  ...
#
#   calculated_host_listings_count_shared_rooms reviews_per_month has_reviews  \
# 0                                           0              1.87           1
# 1                                           0              3.99           1
# 2                                           0              4.81           1
# 3                                           0              3.36           1
# 4                                           0              0.97           1
#
#    first_review_missing  last_review_missing days_since_first_review  \
# 0                     0                    0                    5072
# 1                     0                    0                    5577
# 2                     0                    0                    5371
# 3                     0                    0                    5509
# 4                     0                    0                    5525
#
#   days_since_last_review  superhost_missing  availability_missing has_license
# 0                     82                  0                     0           0
# 1                     82                  0                     0           0
# 2                     81                  0                     0           0
# 3                     94                  0                     0           0
# 4                     88                  0                     0           0
#
# [5 rows x 62 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5850 entries, 0 to 5849
# Data columns (total 62 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            5850 non-null   int64
#  1   last_scraped                                  5850 non-null   object
#  2   name                                          5850 non-null   object
#  3   host_since                                    5850 non-null   object
#  4   host_response_time                            5850 non-null   object
#  5   host_response_rate                            5850 non-null   float64
#  6   host_acceptance_rate                          5850 non-null   float64
#  7   host_is_superhost                             5850 non-null   int64
#  8   host_listings_count                           5850 non-null   float64
#  9   host_total_listings_count                     5850 non-null   float64
#  10  host_has_profile_pic                          5850 non-null   object
#  11  host_identity_verified                        5850 non-null   object
#  12  neighbourhood_cleansed                        5850 non-null   object
#  13  latitude                                      5850 non-null   float64
#  14  longitude                                     5850 non-null   float64
#  15  property_type                                 5850 non-null   object
#  16  room_type                                     5850 non-null   object
#  17  accommodates                                  5850 non-null   int64
#  18  bathrooms                                     5850 non-null   float64
#  19  bathrooms_text                                5850 non-null   object
#  20  bedrooms                                      5850 non-null   float64
#  21  beds                                          5850 non-null   float64
#  22  amenities                                     5850 non-null   object
#  23  price                                         5850 non-null   float64
#  24  minimum_nights                                5850 non-null   int64
#  25  maximum_nights                                5850 non-null   int64
#  26  minimum_minimum_nights                        5850 non-null   float64
#  27  maximum_minimum_nights                        5850 non-null   float64
#  28  minimum_maximum_nights                        5850 non-null   float64
#  29  maximum_maximum_nights                        5850 non-null   float64
#  30  minimum_nights_avg_ntm                        5850 non-null   float64
#  31  maximum_nights_avg_ntm                        5850 non-null   float64
#  32  has_availability                              5850 non-null   int64
#  33  availability_30                               5850 non-null   int64
#  34  availability_60                               5850 non-null   int64
#  35  availability_90                               5850 non-null   int64
#  36  availability_365                              5850 non-null   int64
#  37  number_of_reviews                             5850 non-null   int64
#  38  number_of_reviews_ltm                         5850 non-null   int64
#  39  number_of_reviews_l30d                        5850 non-null   int64
#  40  number_of_reviews_ly                          5850 non-null   int64
#  41  review_scores_rating                          5850 non-null   float64
#  42  review_scores_accuracy                        5850 non-null   float64
#  43  review_scores_cleanliness                     5850 non-null   float64
#  44  review_scores_checkin                         5850 non-null   float64
#  45  review_scores_communication                   5850 non-null   float64
#  46  review_scores_location                        5850 non-null   float64
#  47  review_scores_value                           5850 non-null   float64
#  48  instant_bookable                              5850 non-null   object
#  49  calculated_host_listings_count                5850 non-null   int64
#  50  calculated_host_listings_count_entire_homes   5850 non-null   int64
#  51  calculated_host_listings_count_private_rooms  5850 non-null   int64
#  52  calculated_host_listings_count_shared_rooms   5850 non-null   int64
#  53  reviews_per_month                             5850 non-null   float64
#  54  has_reviews                                   5850 non-null   int64
#  55  first_review_missing                          5850 non-null   int64
#  56  last_review_missing                           5850 non-null   int64
#  57  days_since_first_review                       5850 non-null   int64
#  58  days_since_last_review                        5850 non-null   int64
#  59  superhost_missing                             5850 non-null   int64
#  60  availability_missing                          5850 non-null   int64
#  61  has_license                                   5850 non-null   int64
# dtypes: float64(24), int64(26), object(12)
# memory usage: 2.8+ MB

# %% [markdown]
# ### Encoding 'room_type', 'property-type' and 'neighbourhood_cleansed' as they have limited categorical values.

# %%
df=pd.get_dummies(df,columns=['room_type','property_type','neighbourhood_cleansed'])

# %% [markdown]
# ### Deal with 'amenities' : This is very complex to deal with as there are many amenities associated with some airbnb's, so lets gather the top 30 amenities and create a feature for each.

# %% [markdown]
# #### Helping function

# %%
def parse_amenities(s):##Ai
    if pd.isna(s): return []
    s = str(s).strip()
    if s.startswith("{") and s.endswith("}"):
        s = s[1:-1]
    parts = [p.strip().strip('"').strip("'") for p in s.split(",") if p.strip()!='']
    return [p for p in parts if p]

# parse
amen_lists = df['amenities'].apply(parse_amenities)

# top-K
K = 30
counter = Counter()
for lst in amen_lists:
    counter.update(lst)
top_k = [a for a,c in counter.most_common(K)]

# create binary columns for top-K
for amen in top_k:
    col = "amenity__" + amen.replace(" ", "_").replace(":", "").replace("/", "_")
    df[col] = amen_lists.apply(lambda lst: 1 if amen in lst else 0)

# amenities count
df['amenities_count'] = amen_lists.apply(len)
df=df.drop(columns=['amenities'])

# %% [markdown]
# ### Now for bathroom_text from this we just need to extract the type(shared or private) and create a new feature bathroom_private having binary answers.

# %%
def extract_bathroom_type(text):
    if pd.isna(text):
        return 1  # assume private unless "shared"
    t = text.lower()
    if "shared" in t:
        return 0
    return 1

df['bathroom_private'] = df['bathrooms_text'].apply(extract_bathroom_type)

# drop the original messy column
df = df.drop(columns=['bathrooms_text'])

# %% [markdown]
# ### Lastly host_response_time, we use ordinal encoding to encode this feature.

# %%
mappings={
    'within an hour':4,'within a few hours':3,'within a day':2,'a few days or more':1,'unknown':0
}
df['encoded_host_response_time']=df['host_response_time'].map(mappings)
#dropping the original feature as its useless now.
df=df.drop(columns=['host_response_time'])

# %% [markdown]
# ### Dealing with 'instant_bookable' and mapping the values.

# %%
df['instant_bookable']=df['instant_bookable'].map({'t':1,'f':0})

# %% [markdown]
# ### Dealing with host identity verification and profile pic presence.

# %%
df['host_identity_verified']=df['host_identity_verified'].map({'t':1,'f':0})
df['host_has_profile_pic']=df['host_has_profile_pic'].map({'t':1,'f':0})

# %% [markdown]
# ### Dealing with 'last_scraped' and 'host_since' and converting dates to numeric days values.

# %%
df['last_scraped']=pd.to_datetime(df['last_scraped'])
df['host_since']=pd.to_datetime(df['host_since'])
df['last_scraped']=(pd.Timestamp.today()-df['last_scraped']).dt.days 
df['host_since']=(pd.Timestamp.today()-df['host_since']).dt.days

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5850 entries, 0 to 5849
# Columns: 172 entries, id to encoded_host_response_time
# dtypes: bool(83), float64(24), int64(64), object(1)
# memory usage: 4.4+ MB

# %%
df.to_csv('mlpreprocessed.csv',index=False)

# %% [markdown]
# # END
